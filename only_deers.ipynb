# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data/Statistics-2023-12-21 19-51-57-0118.csv")

# %%
df.head()
# Out:
#    population    health  mating_cooldown_seconds  reproduction_time_seconds  \
# 0          57  100.1729                 59.98208                   5.009433
# 1          59  100.2394                 59.90374                   5.006375
# 2          60  100.3627                 59.90762                   5.005581
# 3          60  100.3627                 59.90762                   5.005581
# 4          60  100.3627                 59.90762                   5.005581
#
#    grow_into_adult_duration_seconds
# 0                          99.90440
# 1                          99.86414
# 2                          99.83210
# 3                          99.83210
# 4                          99.83210

# %%
fig, axs = plt.subplots(nrows=len(df.columns), figsize=(20, 20))

for index, column in enumerate(df.columns):
    sns.lineplot(x=df.index, y=column, data=df, ax=axs[index])
